# %%
from pandas import DataFrame as df

# %%
abs_df = df({'word': ['brownchagoortp', 'the', 'neurocognition', 'of', 'language', 'oxford', 'oxford', 'university','1998', 'brain', 'potentials', 'and', 'syntactic', 'violations', 'revisited', ':', 'no', 'evof', 'the', 'syntactic', 'positive', 'shift', '.', 'neuropsychologia', '36', '217', '226', '15', 'obereckerrfriedrichmfriedericiad', 
'of', 'syntactic', 'processing', 'in', 'two-year-olds', '.', 'journal', 'of']})

# %%
abs_df
# Out:
#                                 word
# 0                     brownchagoortp
# 1                                the
# 2                     neurocognition
# 3                                 of
# 4                           language
# 5                             oxford
# 6                             oxford
# 7                         university
# 8                               1998
# 9                              brain
# 10                        potentials
# 11                               and
# 12                         syntactic
# 13                        violations
# 14                         revisited
# 15                                 :
# 16                                no
# 17                              evof
# 18                               the
# 19                         syntactic
# 20                          positive
# 21                             shift
# 22                                 .
# 23                  neuropsychologia
# 24                                36
# 25                               217
# 26                               226
# 27                                15
# 28  obereckerrfriedrichmfriedericiad
# 29                                of
# 30                         syntactic
# 31                        processing
# 32                                in
# 33                     two-year-olds
# 34                                 .
# 35                           journal
# 36                                of

# %%
test = abs_df.groupby(['word']).size().reset_index(name='counts')

# %%
test
# Out:
#                                 word  counts
# 0                                  .       2
# 1                                 15       1
# 2                               1998       1
# 3                                217       1
# 4                                226       1
# 5                                 36       1
# 6                                  :       1
# 7                                and       1
# 8                              brain       1
# 9                     brownchagoortp       1
# 10                              evof       1
# 11                                in       1
# 12                           journal       1
# 13                          language       1
# 14                    neurocognition       1
# 15                  neuropsychologia       1
# 16                                no       1
# 17  obereckerrfriedrichmfriedericiad       1
# 18                                of       3
# 19                            oxford       2
# 20                          positive       1
# 21                        potentials       1
# 22                        processing       1
# 23                         revisited       1
# 24                             shift       1
# 25                         syntactic       3
# 26                               the       2
# 27                     two-year-olds       1
# 28                        university       1
# 29                        violations       1

# %%
test.to_csv("test.csv", index=False)

# %%
q,w,e,r,t = [3,9],[2,0],[5,7],[1,8],[4,6]

# %%
q
# Out:
# [3, 9]

# %%
w.extend(r)

# %%
w
# Out:
# [2, 0, 1, 8, 1, 8, 1, 8]
